# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
archivo = "../data/Temixco_2018_patched_corrected_may2019_V1p0.csv"
datos = pd.read_csv(archivo,index_col=0,parse_dates=True)
datos.index
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:10:00',
#                '2018-01-01 00:20:00', '2018-01-01 00:30:00',
#                '2018-01-01 00:40:00', '2018-01-01 00:50:00',
#                '2018-01-01 01:00:00', '2018-01-01 01:10:00',
#                '2018-01-01 01:20:00', '2018-01-01 01:30:00',
#                ...
#                '2018-12-31 22:20:00', '2018-12-31 22:30:00',
#                '2018-12-31 22:40:00', '2018-12-31 22:50:00',
#                '2018-12-31 23:00:00', '2018-12-31 23:10:00',
#                '2018-12-31 23:20:00', '2018-12-31 23:30:00',
#                '2018-12-31 23:40:00', '2018-12-31 23:50:00'],
#               dtype='datetime64[ns]', name='time', length=52560, freq=None)

# %%
datos.dtypes
# Out:
# Ib    float64
# Ig    float64
# To    float64
# RH    float64
# WS    float64
# WD    float64
# P     float64
# dtype: object

# %%
datos.describe()
# Out:
#                  Ib            Ig            To            RH            WS  \
# count  52423.000000  52423.000000  52560.000000  52560.000000  52560.000000
# mean     231.966984    257.204853     22.901525     45.032952      1.910955
# std      326.419998    345.839631      4.439300     19.374310      1.045208
# min        0.000000      0.000000      8.160000      5.648000      0.043000
# 25%        0.001000      0.000000     19.410000     29.750000      1.182000
# 50%        0.248000      3.311000     22.730000     42.505000      1.793000
# 75%      528.900000    533.700000     26.140000     58.950000      2.470000
# max     1021.000000   1348.000000     35.870000     97.700000     14.860000
#
#                 WD             P
# count  52560.00000  52560.000000
# mean     211.11866  87589.861622
# std      108.60969    344.590082
# min        0.00000  46552.350000
# 25%      136.30000  87429.140000
# 50%      211.90000  87595.625000
# 75%      319.30000  87764.000000
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52560 entries, 2018-01-01 00:00:00 to 2018-12-31 23:50:00
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ib      52423 non-null  float64
#  1   Ig      52423 non-null  float64
#  2   To      52560 non-null  float64
#  3   RH      52560 non-null  float64
#  4   WS      52560 non-null  float64
#  5   WD      52560 non-null  float64
#  6   P       52560 non-null  float64
# dtypes: float64(7)
# memory usage: 3.2 MB

# %%
datos.plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
datos.columns
# Out:
# Index(['Ib', 'Ig', 'To', 'RH', 'WS', 'WD', 'P'], dtype='object')

# %%
datos["Ib"].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
datos.Ib.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
datos[["Ig","Ib"]].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
datos[["Ig","Ib"]].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %%
datos.plot(subplots=True,figsize=(10,10))
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)

# %%
# datos.Ig.plot()
datos[["Ig","Ib"]].plot(subplots=True,figsize=(10,6))
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %%
datos.loc["2018-03"].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)

# %%
# pip show pandas

# %%
datos.Ig.loc["2018-03-10 12:00":"2018-03-10 23:00"].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>], dtype=object)
